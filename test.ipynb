# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array([[80, 0.329488, 0.025073],
[81, 0.311366, 0.025325],
[82, 0.294316, 0.025340],
[83, 0.278244, 0.025219],
[84, 0.262939, 0.025230],
[85, 0.248865, 0.025580],
[86, 0.235342, 0.025553],
[87, 0.222648, 0.025274],
[88, 0.210848, 0.025068],
[89, 0.199554, 0.025025],
[90, 0.189094, 0.025159],
[91, 0.179364, 0.024862],
[92, 0.170005, 0.024882],
[93, 0.161374, 0.024812],
[94, 0.153262, 0.024731],
[95, 0.145688, 0.024652],
[96, 0.138703, 0.024783],
[97, 0.131920, 0.024680],
[98, 0.125410, 0.024708],
[99, 0.119508, 0.024619]])

epochs = arr[:,0]
tloss = arr[:,1]
vloss = arr[:,2]

plt.plot(epochs, tloss)
plt.plot(epochs, vloss)
plt.show()

# %%
arr = np.array([[180,	0.014777,	0.018908],
[181,	0.014528,	0.018933],
[182,	0.014333,	0.018840],
[183,	0.014086,	0.018492],
[184,	0.013996,	0.018115],
[185,	0.013934,	0.018090],
[186,	0.013744,	0.018044],
[187,	0.013596,	0.018019],
[188,	0.013329,	0.017962],
[189,	0.013250,	0.017840],
[190,	0.013111,	0.017666],
[191,	0.012939,	0.017684],
[192,	0.012972,	0.017691],
[193,	0.012905,	0.017684],
[194,	0.012899,	0.017692],
[195,	0.012686,	0.017719],
[196,	0.012719,	0.017691],
[197,	0.012649,	0.017705],
[198,	0.012612,	0.017669],
[199,	0.012504,	0.017630]])

epochs = arr[:,0]
tloss = arr[:,1]
vloss = arr[:,2]

plt.plot(epochs, tloss)
plt.plot(epochs, vloss)
plt.show()
